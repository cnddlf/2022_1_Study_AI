# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2022_1_Study_AI/data/cats_and_dogs
# !unzip --qq "/content/drive/MyDrive/2022_1_Study_AI/data/cats_and_dogs/cats_and_dogs-20220317T070632Z-001.zip"
# Out:
# /content/drive/MyDrive/2022_1_Study_AI/data/cats_and_dogs
